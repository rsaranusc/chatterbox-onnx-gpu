# %%
# %cd /content/
# !rm -rf chatterbox-onnx-gpu
# Out:
# /content

# %%
# !git clone https://github.com/rsaranusc/chatterbox-onnx-gpu -q
# %cd chatterbox-onnx-gpu
# !pip install -r requirements.txt -q
# !mkdir input
# !mkdir output
# Out:
# /content/chatterbox-onnx-gpu
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.5/300.5 MB 4.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.5 MB/s eta 0:00:00
# mkdir: cannot create directory ‘input’: File exists

# %%
# %cd input/

# %%
# !wget -r "https://grsdb-23-162-40-46.a.free.pinggy.link/Pickup/pua-mrm-crit/1_positionality_statement.md"
# Out:
# --2025-11-27 03:20:36--  https://grsdb-23-162-40-46.a.free.pinggy.link/Pickup/pua-mrm-crit/1_positionality_statement.md
# Resolving grsdb-23-162-40-46.a.free.pinggy.link (grsdb-23-162-40-46.a.free.pinggy.link)... 194.213.18.243, 2a10:1fc0:a::707:fb80, 2a10:1fc0:a::e0fe:1ad0, ...
# Connecting to grsdb-23-162-40-46.a.free.pinggy.link (grsdb-23-162-40-46.a.free.pinggy.link)|194.213.18.243|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4036 (3.9K) [text/markdown]
# Saving to: ‘grsdb-23-162-40-46.a.free.pinggy.link/Pickup/pua-mrm-crit/1_positionality_statement.md’
#
# grsdb-23-162-40-46. 100%[===================>]   3.94K  --.-KB/s    in 0s
#
# 2025-11-27 03:20:37 (70.6 MB/s) - ‘grsdb-23-162-40-46.a.free.pinggy.link/Pickup/pua-mrm-crit/1_positionality_statement.md’ saved [4036/4036]
#
# FINISHED --2025-11-27 03:20:37--
# Total wall clock time: 0.6s
# Downloaded: 1 files, 3.9K in 0s (70.6 MB/s)

# %%
# %pwd
# Out:
# '/content/chatterbox-onnx-gpu/input'

# %%
# %cd ..
# Out:
# /content/chatterbox-onnx-gpu

# %%
# !python chatterbox.py -i ./input/ -o ./output/ -v ./en-Rob_man.wav
# Out:
# python3: can't open file '/content/chatterbox-onnx-gpu/input/chatterbox.py': [Errno 2] No such file or directory
